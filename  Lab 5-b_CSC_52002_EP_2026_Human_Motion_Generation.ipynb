# %% [markdown]
# # Lab 5(b) CSC_52002_EP_2026:  Human motion generation
#
# Please refer to the attached PDF for compelete description.
#
# Submission For the final results, please upload your Google Colab notebook with [__all rendered views__] and written answers kept within the file.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Setup dataset
# Please access this Google Drive folder: [link](https://drive.google.com/drive/folders/1V5yzlwBPSNVPj33SfDHnvMykXISh3CyB?usp=sharing) and create a shortcut in the root of your Google Drive `/content/drive/MyDrive/`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/humanml3d-data
# Out:
# Mounted at /content/drive
# caption_clip  checkpoints		smplh
# caption_raw   humanml3d_test_split.txt	smpl_rifke

# %% [markdown]
# ### Setup environment

# %% [markdown]
# Make sure you're running on a T4 GPU Colab instance; if not, activate it.
#
# Tips:
# If you are using **Google Colab** and encounter errors with **pyrender** (e.g., installation fails or videos do not render), please try one of these solutions: (1) __Downgrade pyrender__: Install version 0.1.45.Roll back the environment; (2) **Roll back your Google Colab runtime** to July 2025 (this is usually the faster solution).

# %%
# !nvidia-smi
# Out:
# Sun Feb 15 21:47:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Upload the unzip files (including folders) that you download from Moodle.

# %%
# !ln -s /content/drive/MyDrive/humanml3d-data ./ # Plug the dataset in the repo

# %% [markdown]
# Install required libraries

# %%
# !pip install hydra-core
# !pip install pyrender
# If you are using **Google Colab** and encounter errors with **pyrender** (e.g., installation fails or videos do not render), please try one of these solutions: (1) __Downgrade pyrender__: Install version 0.1.45.Roll back the environment; (2) **Roll back your Google Colab runtime** to July 2025 (this is usually the faster solution).
# !pip install smplx
# !pip install torchtyping
# !pip install lightning
# !pip install ema_pytorch
# Out:
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hydra-core) (26.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0.3)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: hydra-core
# Successfully installed hydra-core-1.3.2
# Collecting pyrender
#   Downloading pyrender-0.1.45-py3-none-any.whl.metadata (1.5 kB)
# Collecting freetype-py (from pyrender)
#   Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from pyrender) (2.37.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pyrender) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyrender) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from pyrender) (11.3.0)
# Collecting pyglet>=1.4.10 (from pyrender)
#   Downloading pyglet-2.1.13-py3-none-any.whl.metadata (7.7 kB)
# Collecting PyOpenGL==3.1.0 (from pyrender)
#   Downloading PyOpenGL-3.1.0.zip (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 37.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyrender) (1.16.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from pyrender) (1.17.0)
# Collecting trimesh (from pyrender)
#   Downloading trimesh-4.11.2-py3-none-any.whl.metadata (13 kB)
# Downloading pyrender-0.1.45-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.0 MB/s eta 0:00:00
# Downloading pyglet-2.1.13-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.5 MB/s eta 0:00:00
# Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.0 MB/s eta 0:00:00
# Downloading trimesh-4.11.2-py3-none-any.whl (740 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 740.3/740.3 kB 59.2 MB/s eta 0:00:00
# Building wheels for collected packages: PyOpenGL
#   Building wheel for PyOpenGL (setup.py) ... done
#   Created wheel for PyOpenGL: filename=PyOpenGL-3.1.0-py3-none-any.whl size=1745193 sha256=4dfa25ea3b5ac3d987f723aca67e6b46d5e6f828418711ed4080493f21d0771f
#   Stored in directory: /root/.cache/pip/wheels/5c/d0/77/e69597cdbcb72ea27345036f549a737909bcf17c39789472ce
# Successfully built PyOpenGL
# Installing collected packages: PyOpenGL, trimesh, pyglet, freetype-py, pyrender
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.10
#     Uninstalling PyOpenGL-3.1.10:
#       Successfully uninstalled PyOpenGL-3.1.10
# Successfully installed PyOpenGL-3.1.0 freetype-py-2.5.1 pyglet-2.1.13 pyrender-0.1.45 trimesh-4.11.2
# Collecting smplx
#   Downloading smplx-0.1.28-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from smplx) (2.0.2)
# Requirement already satisfied: torch>=1.0.1.post2 in /usr/local/lib/python3.12/dist-packages (from smplx) (2.9.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.1.post2->smplx) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.1.post2->smplx) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.1.post2->smplx) (3.0.3)
# Downloading smplx-0.1.28-py3-none-any.whl (29 kB)
# Installing collected packages: smplx
# Successfully installed smplx-0.1.28
# Collecting torchtyping
#   Downloading torchtyping-0.1.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from torchtyping) (2.9.0+cu128)
# Collecting typeguard<3,>=2.11.1 (from torchtyping)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->torchtyping) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7.0->torchtyping) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.0->torchtyping) (3.0.3)
# Downloading torchtyping-0.1.5-py3-none-any.whl (17 kB)
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, torchtyping
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.4
#     Uninstalling typeguard-4.4.4:
#       Successfully uninstalled typeguard-4.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed torchtyping-0.1.5 typeguard-2.13.3
# Collecting lightning
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging<27.0,>=23.0 in /usr/local/lib/python3.12/dist-packages (from lightning) (26.0)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lightning) (2.9.0+cu128)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from lightning) (4.67.3)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /usr/local/lib/python3.12/dist-packages (from lightning) (4.15.0)
# Collecting pytorch-lightning (from lightning)
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning) (3.13.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.5.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics<3.0,>0.7.0->lightning) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (1.22.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.3)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning) (3.11)
# Downloading lightning-2.6.1-py3-none-any.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 30.4 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 72.9 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 58.6 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning, lightning
# Successfully installed lightning-2.6.1 lightning-utilities-0.15.2 pytorch-lightning-2.6.1 torchmetrics-1.8.2
# Collecting ema_pytorch
#   Downloading ema_pytorch-0.7.9-py3-none-any.whl.metadata (897 bytes)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.12/dist-packages (from ema_pytorch) (2.9.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0->ema_pytorch) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0->ema_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0->ema_pytorch) (3.0.3)
# Downloading ema_pytorch-0.7.9-py3-none-any.whl (11 kB)
# Installing collected packages: ema_pytorch
# Successfully installed ema_pytorch-0.7.9

# %% [markdown]
# ## Human motion dataset and representation

# %% [markdown]
# ### HumanML3D dataset

# %% [markdown]
# #### Question 1:
# *Answer here...*

# %% [markdown]
# ### SMPL representation

# %% [markdown]
# #### Question 2:
# *Answer here...*

# %%
# !git clone https://github.com/kimnam1/lab5-b
# Out:
# fatal: destination path 'lab5-b' already exists and is not an empty directory.

# %%
# !cp -r /content/lab5-b/* /content/

# %% [markdown]
# #### Code 2
# *Complete `visualize_smpl.py`*

# %%
# !cd /content/lab5-b
# !python src/visualize_smpl.py --cfg job | sed -n '1,200p'
# Out:
# Traceback (most recent call last):
#   File "/content/lab5-b/src/visualize_smpl.py", line 8, in <module>
#     from utils.rendering_utils import smpl_to_mp4
# ModuleNotFoundError: No module named 'utils'

# %%
import sys
sys.path.append('/content/lab5-b')

# %%
# !HYDRA_FULL_ERROR=1 PYTHONPATH=$(pwd) python src/visualize_smpl.py

import moviepy.editor
moviepy.editor.ipython_display("./smpl.mp4")
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# [2026-02-15 22:04:19,343][numexpr.utils][INFO] - NumExpr defaulting to 2 threads.
# Error executing job with overrides: []
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py", line 92, in _call_target
#     return _target_(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lab5-b/src/datasets/modalities/human_dataset.py", line 49, in __init__
#     self.body_model = build_layer(**kwargs["smpl_kwargs"])
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/smplx/body_models.py", line 2345, in build_layer
#     raise ValueError(f'Unknown model type {model_type}, exiting!')
# ValueError: Unknown model type humanml3d-data, exiting!
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/lab5-b/src/visualize_smpl.py", line 34, in <module>
#     main()
#   File "/usr/local/lib/python3.12/dist-packages/hydra/main.py", line 94, in decorated_main
#     _run_hydra(
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/utils.py", line 457, in _run_app
#     run_and_report(
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/utils.py", line 223, in run_and_report
#     raise ex
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#            ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/utils.py", line 458, in <lambda>
#     lambda: hydra.run(
#             ^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/hydra.py", line 132, in run
#     _ = ret.return_value
#         ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/core/utils.py", line 260, in return_value
#     raise self._return_value
#   File "/usr/local/lib/python3.12/dist-packages/hydra/core/utils.py", line 186, in run_job
#     ret.return_value = task_function(task_cfg)
#                        ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lab5-b/src/visualize_smpl.py", line 17, in main
#     dataset = instantiate(config.dataset).set_split("test")
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py", line 226, in instantiate
#     return instantiate_node(
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py", line 342, in instantiate_node
#     value = instantiate_node(
#             ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py", line 347, in instantiate_node
#     return _call_target(_target_, partial, args, kwargs, full_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py", line 97, in _call_target
#     raise InstantiationException(msg) from e
# hydra.errors.InstantiationException: Error in call to target 'src.datasets.modalities.human_dataset.HumanDataset':
# ValueError('Unknown model type humanml3d-data, exiting!')
# full_key: dataset.human
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-665926471.py in <cell line: 0>()
#       2
#       3 import moviepy.editor
# ----> 4 moviepy.editor.ipython_display("./smpl.mp4")
#
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/html_tools.py in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     218         clip = clip.to_ImageClip(t)
#     219
# --> 220     return HTML2(html_embed(clip, filetype=filetype, maxduration=maxduration,
#     221                 center=center, rd_kwargs=rd_kwargs, **html_kwargs))
#
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/html_tools.py in html_embed(clip, filetype, maxduration, rd_kwargs, center, **html_kwargs)
#     138     if filetype in ['audio', 'video']:
#     139
# --> 140         duration = ffmpeg_parse_infos(filename)['duration']
#     141         if duration > maxduration:
#     142             raise ValueError("The duration of video %s (%.1f) exceeds the 'maxduration' "%(filename, duration)+
#
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py in ffmpeg_parse_infos(filename, print_infos, check_duration, fps_source)
#     268     lines = infos.splitlines()
#     269     if "No such file or directory" in lines[-1]:
# --> 270         raise IOError(("MoviePy error: the file %s could not be found!\n"
#     271                       "Please check that you entered the correct "
#     272                       "path.")%filename)
#
# OSError: MoviePy error: the file ./smpl.mp4 could not be found!
# Please check that you entered the correct path.

# %% [markdown]
# ## Model architectures

# %% [markdown]
# ### Config A: Incontext

# %% [markdown]
# #### Code 3
# *Complete `src/models/modules/incontext.py`*

# %%
# !PYTHONPATH=$(pwd) python src/models/modules/incontext.py

# %% [markdown]
# ### Config B: AdaLN

# %% [markdown]
# #### Question 3:
# *Answer here...*

# %% [markdown]
# #### Code 4
# *Complete `src/models/modules/adaln.py`*

# %%
# !PYTHONPATH=$(pwd) python src/models/modules/adaln.py

# %% [markdown]
# ### Config C: Cross attention

# %% [markdown]
# #### Question 4:
# *Answer here...*

# %% [markdown]
# #### Code 5
# *Complete `src/models/modules/cross attention.py`*

# %%
# !PYTHONPATH=$(pwd) python src/models/modules/cross_attention.py

# %% [markdown]
# #### Question 5:
# *Answer here...*

# %% [markdown]
# ## Diffusion framework

# %% [markdown]
# ### DDPM

# %% [markdown]
# #### Code 6
# *Complete `src/training/losses/ddpm.py`*

# %%
# !PYTHONPATH=$(pwd) python src/training/losses/ddpm.py

# %% [markdown]
# #### Code 7
# *Complete `src/training/sampler/ddpm.py`*

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/sampler@diffuser.test_sampler=ddpm seed=2

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_incontext.mp4")

# %% [markdown]
# ### DDIM

# %% [markdown]
# #### Question 6:
# *Answer here...*

# %% [markdown]
# #### Code 8
# *Complete `src/training/sampler/ddim.py`*

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/sampler@diffuser.test_sampler=ddim seed=2

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddim_incontext.mp4")

# %% [markdown]
# #### Question 7:
# *Answer here...*

# %% [markdown]
# ## Result analysis

# %% [markdown]
# ### Qualitative analysis

# %% [markdown]
# #### Code 9

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/network=incontext \
checkpoint_path=./humanml3d-data/checkpoints/incontext.ckpt

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_incontext.mp4")

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/network=adaln \
checkpoint_path=./humanml3d-data/checkpoints/adaln.ckpt

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_adaln.mp4")

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/network=cross_attention \
checkpoint_path=./humanml3d-data/checkpoints/cross_attention.ckpt

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_cross_attention.mp4")

# %% [markdown]
# #### Question 8
# *Answer here...*

# %% [markdown]
# ### Quantitative analysis

# %% [markdown]
# #### Question 9:
# *Answer here...*

# %% [markdown]
# #### Code 10
# *Complete src/metrics/frechet.py*

# %% [markdown]
# #### Code 11
# *Complete src/metrics/similarity.py*

# %% [markdown]
# #### Code 12

# %% [markdown]
# #### Bonus 1:
# *Answer here...*

# %%
# !PYTHONPATH=$(pwd) python src/evaluate.py diffuser/network=incontext \
checkpoint_path=./humanml3d-data/checkpoints/incontext.ckpt

# %%
# !PYTHONPATH=$(pwd) python src/evaluate.py diffuser/network=adaln \
checkpoint_path=./humanml3d-data/checkpoints/adaln.ckpt

# %%
# !PYTHONPATH=$(pwd) python src/evaluate.py diffuser/network=cross_attention \
checkpoint_path=./humanml3d-data/checkpoints/cross_attention.ckpt

# %% [markdown]
# #### Question 10:
# *Answer here...*

# %% [markdown]
# #### Bonus 2:
# *Answer here...*
